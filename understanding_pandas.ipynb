# %% [markdown]
# <a href="https://colab.research.google.com/github/YogenderSingh07/ibm-ml-learning/blob/main/understanding_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import numpy as np

# %%
##multiple cols -- data frame
##single col -- series



df = pd.read_csv('housing.csv')
df.info() #gives the whole info about the data..for eg the data type
## rows and cols--df.shape()
df.head() ## first 5 rows
df.tail() ## last 5 rows
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2521453947.py in <cell line: 0>()
#       4
#       5
# ----> 6 df = pd.read_csv('housing.csv')
#       7 df.info() #gives the whole info about the data..for eg the data type
#       8 ## rows and cols--df.shape()
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'housing.csv'

# %%
#COLS

## to access data of more than one column(can be called dataframe),use square brackets twice
df[['longitude','latitude']]
# to know unique values of cols, df[colname].unique()
df['longitude'].unique()

#length of these unique vals can be found through the len() function
len(df['longitude'].unique())
#rename a column, pass old name as key & new name as a value(key-val pair)
df.rename(columns={'longitude:height'},axis=1)

#the data wont be updated permanently, to update it permanently,put inplace=true else variable reassignment like df = changes
df.rename(columns={'longitude:height'},inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3229964696.py in <cell line: 0>()
#       9 len(df['longitude'].unique())
#      10 #rename a column, pass old name as key & new name as a value(key-val pair)
# ---> 11 df.rename(columns={'longitude:height'},axis=1)
#      12
#      13 #the data wont be updated permanently, to update it permanently,put inplace=true else variable reassignment like df = changes
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    5765         4  3  6
#    5766         """
# -> 5767         return super()._rename(
#    5768             mapper=mapper,
#    5769             index=index,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    1088         if index is not None or columns is not None:
#    1089             if axis is not None:
# -> 1090                 raise TypeError(
#    1091                     "Cannot specify both 'axis' and any of 'index' or 'columns'"
#    1092                 )
#
# TypeError: Cannot specify both 'axis' and any of 'index' or 'columns'

# %%
from types import new_class
#ROWS( indexing from 1-104)

df.loc[102] ##loc will give the value of the row with rownum 102 -->will give the 102nd row
df.iloc[102] ## iloc will give the row with 102th index..like python ---> will give 103rd row's data
df.iloc[102:110]##slicing
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2036093876.py in <cell line: 0>()
#       2 #ROWS( indexing from 1-104)
#       3
# ----> 4 df.loc[102] ##loc will give the value of the row with rownum 102 -->will give the 102nd row
#       5 df.iloc[102] ## iloc will give the row with 102th index..like python ---> will give 103rd row's data
#       6 df.iloc[102:110]##slicing
#
# NameError: name 'df' is not defined

# %%
#to acess first 4 rows and 3 cols
df.iloc[0:4,0:3]   ##iloc doesnt need column name to access it, but in order to access from loc,we would need col name for it
df.loc[0:4,['longitude','latitude','housing_median_age']]
# Out:
#    longitude  latitude  housing_median_age
# 0    -122.23     37.88                41.0
# 1    -122.22     37.86                21.0
# 2    -122.24     37.85                52.0
# 3    -122.25     37.85                52.0
# 4    -122.25     37.85                52.0

# %% [markdown]
# ### `drop()` method
#
# The `drop()` method is used to remove specified rows or columns from a DataFrame.
#
# *   To drop rows, specify the `index` or `labels` (row labels) and set `axis=0` (default).
# *   To drop columns, specify the `columns` or `labels` (column names) and set `axis=1`.
# *   `inplace=True` modifies the DataFrame in place, otherwise, it returns a new DataFrame.
#
# Let's drop a few rows and a column for demonstration. We will create a copy first to avoid altering the original `df` permanently.

# %%
df_copy = df.copy()

# Drop rows with index 0 and 1
df_dropped_rows = df_copy.drop(index=[0, 1])
print("DataFrame after dropping rows 0 and 1:")
display(df_dropped_rows.head())

# Drop the 'ocean_proximity' column
df_dropped_col = df_copy.drop(columns=['ocean_proximity'])
print("\nDataFrame after dropping 'ocean_proximity' column:")
display(df_dropped_col.head())
# Out:
# DataFrame after dropping rows 0 and 1:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
# 5       413.0       193.0         4.0368            269700.0        NEAR BAY
# 6      1094.0       514.0         3.6591            299200.0        NEAR BAY
# DataFrame after dropping 'ocean_proximity' column:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0

# %% [markdown]
# ### `duplicated()` and `drop_duplicates()` methods
#
# *   The `duplicated()` method returns a boolean Series indicating whether each row is a duplicate of a previous row.
# *   The `drop_duplicates()` method removes duplicate rows from the DataFrame.
#
# Let's add some duplicate rows to our DataFrame copy to demonstrate.

# %%
df_with_duplicates = df.copy()
# Add some duplicate rows for demonstration
df_with_duplicates = pd.concat([df_with_duplicates, df_with_duplicates.iloc[:5]], ignore_index=True)

print("DataFrame with added duplicate rows (first 10 rows):")
display(df_with_duplicates.head(10))

# Identify duplicate rows
duplicate_rows = df_with_duplicates.duplicated()
print("\nBoolean Series indicating duplicate rows:")
display(duplicate_rows.head(10))

# Drop duplicate rows
df_no_duplicates = df_with_duplicates.drop_duplicates()
print("\nDataFrame after dropping duplicate rows (first 10 rows):")
display(df_no_duplicates.head(10))
print(f"Original rows: {len(df_with_duplicates)}, Rows after dropping duplicates: {len(df_no_duplicates)}")
# Out:
# DataFrame with added duplicate rows (first 10 rows):
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
# 5       413.0       193.0         4.0368            269700.0        NEAR BAY
# 6      1094.0       514.0         3.6591            299200.0        NEAR BAY
# 7      1157.0       647.0         3.1200            241400.0        NEAR BAY
# 8      1206.0       595.0         2.0804            226700.0        NEAR BAY
# 9      1551.0       714.0         3.6912            261100.0        NEAR BAY
# Boolean Series indicating duplicate rows:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool
# DataFrame after dropping duplicate rows (first 10 rows):
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
# 5       413.0       193.0         4.0368            269700.0        NEAR BAY
# 6      1094.0       514.0         3.6591            299200.0        NEAR BAY
# 7      1157.0       647.0         3.1200            241400.0        NEAR BAY
# 8      1206.0       595.0         2.0804            226700.0        NEAR BAY
# 9      1551.0       714.0         3.6912            261100.0        NEAR BAY
# Original rows: 20645, Rows after dropping duplicates: 20640

# %% [markdown]
# ### `reset_index()` method
#
# The `reset_index()` method resets the index of the DataFrame. The old index is added as a new column, and a new default integer index is used.
#
# *   `drop=True` prevents the old index from being added as a new column.
# *   `inplace=True` modifies the DataFrame in place.

# %%
df_reset_example = df.iloc[5:10].copy()
print("Original DataFrame slice:")
display(df_reset_example)

# Reset index, keeping the old index as a column
df_reset_with_col = df_reset_example.reset_index()
print("\nDataFrame after `reset_index()` (old index becomes a column):")
display(df_reset_with_col)

# Reset index, dropping the old index
df_reset_dropped = df_reset_example.reset_index(drop=True)
print("\nDataFrame after `reset_index(drop=True)` (old index is dropped):")
display(df_reset_dropped)
# Out:
# Original DataFrame slice:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 5       413.0       193.0         4.0368            269700.0        NEAR BAY
# 6      1094.0       514.0         3.6591            299200.0        NEAR BAY
# 7      1157.0       647.0         3.1200            241400.0        NEAR BAY
# 8      1206.0       595.0         2.0804            226700.0        NEAR BAY
# 9      1551.0       714.0         3.6912            261100.0        NEAR BAY
# DataFrame after `reset_index()` (old index becomes a column):
#    index  longitude  latitude  housing_median_age  total_rooms  \
# 0      5    -122.25     37.85                52.0        919.0
# 1      6    -122.25     37.84                52.0       2535.0
# 2      7    -122.25     37.84                52.0       3104.0
# 3      8    -122.26     37.84                42.0       2555.0
# 4      9    -122.25     37.84                52.0       3549.0
#
#    total_bedrooms  population  households  median_income  median_house_value  \
# 0           213.0       413.0       193.0         4.0368            269700.0
# 1           489.0      1094.0       514.0         3.6591            299200.0
# 2           687.0      1157.0       647.0         3.1200            241400.0
# 3           665.0      1206.0       595.0         2.0804            226700.0
# 4           707.0      1551.0       714.0         3.6912            261100.0
#
#   ocean_proximity
# 0        NEAR BAY
# 1        NEAR BAY
# 2        NEAR BAY
# 3        NEAR BAY
# 4        NEAR BAY
# DataFrame after `reset_index(drop=True)` (old index is dropped):
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.25     37.85                52.0        919.0           213.0
# 1    -122.25     37.84                52.0       2535.0           489.0
# 2    -122.25     37.84                52.0       3104.0           687.0
# 3    -122.26     37.84                42.0       2555.0           665.0
# 4    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       413.0       193.0         4.0368            269700.0        NEAR BAY
# 1      1094.0       514.0         3.6591            299200.0        NEAR BAY
# 2      1157.0       647.0         3.1200            241400.0        NEAR BAY
# 3      1206.0       595.0         2.0804            226700.0        NEAR BAY
# 4      1551.0       714.0         3.6912            261100.0        NEAR BAY

# %%
#min max mean
print(df['total_rooms'].min())
print(df['total_rooms'].max())
print(df['total_rooms'].mean())
# Out:
# 2.0
# 39320.0
# 2635.7630813953488

# %%
#SORTING COLS
df.sort_values(['housing_median_age']) #ascending is true by default
df.sort_values(['housing_median_age'],ascending = False) #ascending is false for descending order
df.sort_values(['housing_median_age','total_rooms'],ascending=False)#sorting multiple cols
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 15689    -122.43     37.79                52.0       6186.0          1566.0
# 15657    -122.41     37.79                52.0       6016.0          2509.0
# 15659    -122.41     37.79                52.0       5783.0          2747.0
# 15769    -122.44     37.77                52.0       5604.0          1268.0
# 3353     -121.03     40.35                52.0       5486.0          1044.0
# ...          ...       ...                 ...          ...             ...
# 2774     -115.80     33.26                 2.0         96.0            18.0
# 19536    -120.93     37.65                 1.0       2254.0           328.0
# 18972    -122.00     38.23                 1.0       2062.0           343.0
# 3130     -117.95     35.08                 1.0         83.0            15.0
# 12286    -116.95     33.86                 1.0          6.0             2.0
#
#        population  households  median_income  median_house_value  \
# 15689      2065.0      1374.0         5.8543            500001.0
# 15657      3436.0      2119.0         2.5166            275000.0
# 15659      4518.0      2538.0         1.7240            225000.0
# 15769      2023.0      1196.0         4.4085            400000.0
# 3353       1977.0       754.0         2.1833             49500.0
# ...           ...         ...            ...                 ...
# 2774         30.0        16.0         5.3374             47500.0
# 19536       402.0       112.0         4.2500            189200.0
# 18972       872.0       268.0         5.2636            191300.0
# 3130         32.0        15.0         4.8750            141700.0
# 12286         8.0         2.0         1.6250             55000.0
#
#       ocean_proximity
# 15689        NEAR BAY
# 15657        NEAR BAY
# 15659        NEAR BAY
# 15769        NEAR BAY
# 3353           INLAND
# ...               ...
# 2774           INLAND
# 19536          INLAND
# 18972          INLAND
# 3130           INLAND
# 12286          INLAND
#
# [20640 rows x 10 columns]

# %%
#creating a Dataframe --dictionary like key-val pair
users = pd.DataFrame({'user_id':[1,2,3,4],'name':["rishit","yogender","aman","VANSH"]})
messages = pd.DataFrame({'OS':["IOS","ANDROID","ANDROID","IOS"],'Message':["hmm","ok","nice","thankyou"],'user_id':[1,2,3,4]})

# %%
#Concatenate , axis =0 is vertical concatination - the stack dataframe one on top of other, axis =1 To place DataFrames side by side, use axis=1. This is useful when the DataFrames have the same rows (matching indices) but different columns (representing different features or attributes).
pd.concat([users,messages],axis=1)
# Out:
#    user_id      name       OS   Message  user_id
# 0        1    rishit      IOS       hmm        1
# 1        2  yogender  ANDROID        ok        2
# 2        3      aman  ANDROID      nice        3
# 3        4     VANSH      IOS  thankyou        4

# %%
#merge
users.merge(messages,on='user_id')
# Out:
#    user_id      name       OS   Message
# 0        1    rishit      IOS       hmm
# 1        2  yogender  ANDROID        ok
# 2        3      aman  ANDROID      nice
# 3        4     VANSH      IOS  thankyou
